# %% [markdown]
# <a href="https://colab.research.google.com/github/andiunsia/DataScience_240401010009_Andi/blob/main/Pertemuan1_Andi_240401010009.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# Nama : Andi
#
# NIM : 240401010009
#
# Kelas : IF204
#
# ---

# %% [markdown]
# # Latihan Pertemuan 1

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================
# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")

# SEL 2: Variabel dan tipe data dasar
nama = "Andi" # String
angkatan = 2024 # Integer
ipk = 3.75 # Float
aktif = True # Boolean
print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!
# Nama : Andi
# Angkatan: 2024
# IPK : 3.75
# Aktif : True

# %%
# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i in tools:
    print(i)
# Out:
# Tools Data Science yang akan kita pelajari:
# Python
# Google Colab
# Jupyter Notebook
# GitHub

# %%
# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Perkenalkan nama saya {nama} dari {prodi}, angkatan {angkatan}."

perkenalan("Andi", "PJJ Informatika", 2024)
# Out:
# 'Hai! Perkenalkan nama saya Andi dari PJJ Informatika, angkatan 2024.'

# %% [markdown]
# # Kesimpulan
#
# Pengenalan dasar-dasar pemrograman Python sebagai fondasi untuk pembelajaran Data Science. Aktivitas yang dilakukan meliputi :
#
# **Eksekusi Kode Sederhana**
#
#
# **Pengenalan Variabel dan Tipe Data Dasar**
#
# Dipelajari penggunaan tipe data dasar Python, yaitu:
#
# - String (nama)
#
# - Integer (angkatan)
#
# - Float (ipk)
#
# - Boolean (aktif)
#
#
#
# **Struktur Data List dan Perulangan**
#
# Dibuat sebuah list bernama tools yang berisi nama-nama perangkat yang akan digunakan dalam perkuliahan (Python, Google Colab, Jupyter Notebook, GitHub).
#
#
# **Pembuatan Fungsi Sederhana**
#
# Didefinisikan fungsi perkenalan() yang menerima tiga parameter (nama, prodi, angkatan) dan mengembalikan kalimat perkenalan.
#
#
# **Google Colab**
#
# Kode dijalankan pada Google Colab, yang memudahkan proses belajar dan berbagi kode.
